# %%
from pandas import merge
from numpy import arange
#from sklearn.cluster import KMeans
#from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
#import plotly.graph_objs as go
df = pd.read_csv('HealthAnimalBites.csv')

# %%
df.head()
# Out:
#    bite_Year  bite_Month SpeciesIDDesc BreedIDDesc GenderIDDesc       color  \
# 0     1985.0         5.0           DOG         NaN       FEMALE  LIG. BROWN
# 1     1986.0         2.0           DOG         NaN      UNKNOWN   BRO & BLA
# 2     1987.0         5.0           DOG         NaN      UNKNOWN         NaN
# 3     1988.0        10.0           DOG         NaN         MALE   BLA & BRO
# 4     1989.0         8.0           DOG         NaN       FEMALE     BLK-WHT
#
#    vaccination_yrs vaccination_date  victim_zip AdvIssuedYNDesc  \
# 0              1.0           1985-6     40229.0              NO
# 1              NaN              NaN     40218.0              NO
# 2              NaN              NaN     40219.0              NO
# 3              NaN              NaN         NaN              NO
# 4              NaN              NaN         NaN              NO
#
#   WhereBittenIDDesc quarantine_date DispositionIDDesc head_sent_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9003 entries, 0 to 9002
# Data columns (total 16 columns):
# bite_Year            8686 non-null float64
# bite_Month           8686 non-null float64
# SpeciesIDDesc        8885 non-null object
# BreedIDDesc          3759 non-null object
# GenderIDDesc         6477 non-null object
# color                6426 non-null object
# vaccination_yrs      3738 non-null float64
# vaccination_date     4115 non-null object
# victim_zip           7165 non-null float64
# AdvIssuedYNDesc      2565 non-null object
# WhereBittenIDDesc    8387 non-null object
# quarantine_date      2020 non-null object
# DispositionIDDesc    1535 non-null object
# head_sent_date       395 non-null object
# release_date         1445 non-null object
# ResultsIDDesc        1543 non-null object
# dtypes: float64(4), object(12)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (9003, 16)

# %%
#•	Identify missing data
df.isnull()
# Out:
#       bite_Year  bite_Month  SpeciesIDDesc  BreedIDDesc  GenderIDDesc  color  \
# 0         False       False          False         True         False  False
# 1         False       False          False         True         False  False
# 2         False       False          False         True         False   True
# 3         False       False          False         True         False  False
# 4         False       False          False         True         False  False
# 5         False       False          False         True         False   True
# 6         False       False          False         True         False  False
# 7         False       False          False         True         False  False
# 8         False       False          False         True         False  False
# 9         False       False          False         True         False  False
# 10        False       False          False         True         False  False
# ...

# %%
#•	Identify missing data
df.isnull().sum()
# Out:
# bite_Year             317
# bite_Month            317
# SpeciesIDDesc         118
# BreedIDDesc          5244
# GenderIDDesc         2526
# color                2577
# vaccination_yrs      5265
# vaccination_date     4888
# victim_zip           1838
# AdvIssuedYNDesc      6438
# WhereBittenIDDesc     616
# quarantine_date      6983
# DispositionIDDesc    7468
# head_sent_date       8608
# release_date         7558
# ResultsIDDesc        7460
# dtype: int64

# %%
#•	Identify missing data
df.notnull().sum()
# Out:
# bite_Year            8686
# bite_Month           8686
# SpeciesIDDesc        8885
# BreedIDDesc          3759
# GenderIDDesc         6477
# color                6426
# vaccination_yrs      3738
# vaccination_date     4115
# victim_zip           7165
# AdvIssuedYNDesc      2565
# WhereBittenIDDesc    8387
# quarantine_date      2020
# DispositionIDDesc    1535
# head_sent_date        395
# release_date         1445
# ResultsIDDesc        1543
# dtype: int64

# %%
del df['BreedIDDesc']
del df['release_date']
del df['head_sent_date']
del df['ResultsIDDesc']

# %%
df.isnull().sum()
# Out:
# bite_Year             317
# bite_Month            317
# SpeciesIDDesc         118
# GenderIDDesc         2526
# color                2577
# vaccination_yrs      5265
# vaccination_date     4888
# victim_zip           1838
# AdvIssuedYNDesc      6438
# WhereBittenIDDesc     616
# quarantine_date      6983
# DispositionIDDesc    7468
# dtype: int64

# %%
df.notnull().sum()
# Out:
# bite_Year            8686
# bite_Month           8686
# SpeciesIDDesc        8885
# GenderIDDesc         6477
# color                6426
# vaccination_yrs      3738
# vaccination_date     4115
# victim_zip           7165
# AdvIssuedYNDesc      2565
# WhereBittenIDDesc    8387
# quarantine_date      2020
# DispositionIDDesc    1535
# dtype: int64

# %%
#delete (missing value):all > 50%
del df['vaccination_date']

# %%
del df['AdvIssuedYNDesc']

# %%
del df['quarantine_date']

# %%
del df['DispositionIDDesc']

# %%
df.notnull().sum()
# Out:
# bite_Year            8686
# bite_Month           8686
# SpeciesIDDesc        8885
# GenderIDDesc         6477
# color                6426
# vaccination_yrs      3738
# victim_zip           7165
# WhereBittenIDDesc    8387
# dtype: int64

# %%
df.shape
# Out:
# (9003, 8)

# %%
#my data samples are big enough， so I want to save the row which has all the eight values
df2 = df.dropna(thresh = 8)

# %%
df2.head()
# Out:
#     bite_Year  bite_Month SpeciesIDDesc GenderIDDesc       color  \
# 0      1985.0         5.0           DOG       FEMALE  LIG. BROWN
# 6      1990.0         2.0           DOG       FEMALE  BLACK/WHIT
# 41     2009.0        12.0           DOG         MALE     TAN-BRN
# 44     2009.0        12.0           DOG         MALE     BRN-WHT
# 47     2009.0        12.0           DOG       FEMALE     WHT-BRN
#
#     vaccination_yrs  victim_zip WhereBittenIDDesc
# 0               1.0     40229.0              BODY
# 6               1.0     40203.0              BODY
# 41              1.0     40291.0              BODY
# 44              1.0     40165.0              HEAD
# 47              3.0     40291.0              BODY

# %%
#to confirm that data samples saved are still enough or not
df2.shape
# Out:
# (2625, 8)

# %%
#data samples saved are still enough
df2.notnull().sum()
# Out:
# bite_Year            2625
# bite_Month           2625
# SpeciesIDDesc        2625
# GenderIDDesc         2625
# color                2625
# vaccination_yrs      2625
# victim_zip           2625
# WhereBittenIDDesc    2625
# dtype: int64

# %%
df2.dtypes
# Out:
# bite_Year            float64
# bite_Month           float64
# SpeciesIDDesc         object
# GenderIDDesc          object
# color                 object
# vaccination_yrs      float64
# victim_zip           float64
# WhereBittenIDDesc     object
# dtype: object

# %%
#Identify outliers
#Check for overall plausibility and errors
df2.describe()
# Out:
#          bite_Year   bite_Month  vaccination_yrs    victim_zip
# count  2625.000000  2625.000000      2625.000000   2625.000000
# mean   2014.379810     6.409524         1.447238  40427.150095
# std      58.743488     3.052685         0.850247   3049.226508
# min    1952.000000     1.000000         1.000000   6107.000000
# 25%    2011.000000     4.000000         1.000000  40212.000000
# 50%    2013.000000     6.000000         1.000000  40220.000000
# 75%    2015.000000     9.000000         1.000000  40245.000000
# max    5013.000000    12.000000        11.000000  99037.000000

# %%
#Check for overall plausibility and errors (e.g., typos, unreasonable ranges)
df2[df2['bite_Year']>2018]
# Out:
#       bite_Year  bite_Month SpeciesIDDesc GenderIDDesc  color  \
# 4490     5013.0         7.0           DOG       FEMALE  WHITE
# 6505     2201.0         5.0           DOG         MALE  BROWN
#
#       vaccination_yrs  victim_zip WhereBittenIDDesc
# 4490              1.0     40216.0              BODY
# 6505              1.0     40229.0              BODY

# %%
#replace the data out of range
df3 = df2.replace([5013.0, 2201.0], 2013)

# %%
#confirm outliers are replaced
df3[df3['bite_Year']>2018]
# Out:
# Empty DataFrame
# Columns: [bite_Year, bite_Month, SpeciesIDDesc, GenderIDDesc, color, vaccination_yrs, victim_zip, WhereBittenIDDesc]
# Index: []

# %%
#transform some variables into right type
df3['victim_zip']=df3['victim_zip'].astype(np.int64)
df3['bite_Year'] =df3['bite_Year'].astype(np.int64)
df3['bite_Month']=df3['bite_Month'].astype(np.int64)
df3['vaccination_yrs']=df3['vaccination_yrs'].astype(np.int64)

# %%
df3.dtypes
# Out:
# bite_Year             int64
# bite_Month            int64
# SpeciesIDDesc        object
# GenderIDDesc         object
# color                object
# vaccination_yrs       int64
# victim_zip            int64
# WhereBittenIDDesc    object
# dtype: object

# %%
print(df.ix[[0]].values[0][0])
# Out:
# 1985.0
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df3.head()
# Out:
#     bite_Year  bite_Month SpeciesIDDesc GenderIDDesc       color  \
# 0        1985           5           DOG       FEMALE  LIG. BROWN
# 6        1990           2           DOG       FEMALE  BLACK/WHIT
# 41       2009          12           DOG         MALE     TAN-BRN
# 44       2009          12           DOG         MALE     BRN-WHT
# 47       2009          12           DOG       FEMALE     WHT-BRN
#
#     vaccination_yrs  victim_zip WhereBittenIDDesc
# 0                 1       40229              BODY
# 6                 1       40203              BODY
# 41                1       40291              BODY
# 44                1       40165              HEAD
# 47                3       40291              BODY

# %%
df4 = df3[['bite_Year','bite_Month', 'vaccination_yrs','victim_zip']]

# %%
df5 = df3[['bite_Year','bite_Month', 'vaccination_yrs','victim_zip','GenderIDDesc']]

# %%
df4.head(10)
# Out:
#     bite_Year  bite_Month  vaccination_yrs  victim_zip
# 0        1985           5                1       40229
# 6        1990           2                1       40203
# 41       2009          12                1       40291
# 44       2009          12                1       40165
# 47       2009          12                3       40291
# 48       2009          12                3       40229
# 50       2009          12                1       40220
# 51       2009          12                3       40220
# 52       2009          12                1       40220
# 53       2009          12                1       40241

# %%
df5.head(10)
# Out:
#     bite_Year  bite_Month  vaccination_yrs  victim_zip GenderIDDesc
# 0        1985           5                1       40229       FEMALE
# 6        1990           2                1       40203       FEMALE
# 41       2009          12                1       40291         MALE
# 44       2009          12                1       40165         MALE
# 47       2009          12                3       40291       FEMALE
# 48       2009          12                3       40229       FEMALE
# 50       2009          12                1       40220       FEMALE
# 51       2009          12                3       40220         MALE
# 52       2009          12                1       40220         MALE
# 53       2009          12                1       40241         MALE

# %%
result=df4
result.to_csv('new.csv')

# %%
re=df5
re.to_csv('new2.csv')

# %%
df = pd.read_csv('new.csv')

# %%
#resu=df3
#resu.to_csv('new31.xlsx')

# %%
df.head(10)
del df['Unnamed: 0']

# %%
df.head(10)
# Out:
#    bite_Year  bite_Month  vaccination_yrs  victim_zip
# 0       1985           5                1       40229
# 1       1990           2                1       40203
# 2       2009          12                1       40291
# 3       2009          12                1       40165
# 4       2009          12                3       40291
# 5       2009          12                3       40229
# 6       2009          12                1       40220
# 7       2009          12                3       40220
# 8       2009          12                1       40220
# 9       2009          12                1       40241

# %%
# bite_Year has low negative correlation with bite_Month, 
# bite_Year has very low negative correlation with vaccination_yrs and victim_zip
# bite_Month has low negative correlation with bite_Year,vaccination_yrs and victim_zip
# vaccination_yrs has very low negative correlation with bite_Year 
# vaccination_yrs has low negative correlation with bite_Month
# vaccination_yrs has low positive correlation with victim_zip
df3.corr()
# Out:
#                  bite_Year  bite_Month  vaccination_yrs  victim_zip
# bite_Year         1.000000   -0.074958        -0.006619   -0.000155
# bite_Month       -0.074958    1.000000        -0.028306   -0.017321
# vaccination_yrs  -0.006619   -0.028306         1.000000    0.014683
# victim_zip       -0.000155   -0.017321         0.014683    1.000000

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
k = 5           #the number of clusters I want
iteration = 500

# %%
kmodel = KMeans(n_clusters = k, n_jobs = 4) #n_jobs=parallel=CPU
kmodel.fit(df) #fitting
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=4, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
r1 = pd.Series(kmodel.labels_).value_counts()  #claulate classes
r2 = pd.DataFrame(kmodel.cluster_centers_)     #find clustering center
r = pd.concat([r2, r1], axis = 1) #link，get numbers
r.columns = list(df.columns) + [u'number'] 
print (r)
# Out:
#      bite_Year  bite_Month  vaccination_yrs    victim_zip  number
# 0  2013.168892    6.403378         1.444226  40217.203064    2546
# 1  2013.122807    6.368421         1.543860  47074.982456      57
# 2  2013.428571    6.000000         1.571429  86047.857143       7
# 3  2012.750000    7.666667         1.500000  21423.083333      12
# 4  2012.000000    8.333333         1.666667  61861.333333       3

# %%
#distance
print(r2)
# Out:
#              0         1         2             3
# 0  2013.168892  6.403378  1.444226  40217.203064
# 1  2013.122807  6.368421  1.543860  47074.982456
# 2  2013.428571  6.000000  1.571429  86047.857143
# 3  2012.750000  7.666667  1.500000  21423.083333
# 4  2012.000000  8.333333  1.666667  61861.333333

# %%
print(r1)
# Out:
# 0    2546
# 1      57
# 3      12
# 2       7
# 4       3
# dtype: int64

# %%
# %matplotlib inline
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=2625, centers=5,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

# %%
# %matplotlib inline
from collections import Counter
import random

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans, DBSCAN
from scipy.stats import multivariate_normal

# %%
import scipy

from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

from pylab import  rcParams
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import sklearn.metrics as sm

# %%
# %matplotlib inline
import scipy.cluster.hierarchy as sch
import matplotlib.pylab as plt
disMat = sch.distance.pdist(df,'euclidean') 
#hierarchy cluster
Z=sch.linkage(disMat,method='average') 
plt.figure(figsize=(50,20))
#save as plot_dendrogram.png
P=sch.dendrogram(Z)
plt.savefig('plot_dendrogram.png')

# %%
# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=12,  # show only the last p merged clusters
    show_leaf_counts=False,  # otherwise numbers in brackets are counts
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=12,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
cluster= sch.fcluster(Z,t=1,criterion='inconsistent') 

print ("Original cluster by hierarchy clustering:\n",cluster)
# Out:
# Original cluster by hierarchy clustering:
#  [833 833  75 ..., 464 522 464]

# %%
from __future__ import print_function
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import statsmodels.api as sm
from sklearn import linear_model
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import warnings
warnings.filterwarnings('ignore')
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
